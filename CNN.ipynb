# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(12, 8))

    # Draw Conv1 Layer
    rect1 = patches.FancyBboxPatch((0.05, 0.7), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightblue', linewidth=2)
    ax.add_patch(rect1)
    plt.text(0.15, 0.8, 'Conv1\n(num_input_time_steps, 6, 3)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw Pool1 Layer
    rect2 = patches.FancyBboxPatch((0.3, 0.7), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightgreen', linewidth=2)
    ax.add_patch(rect2)
    plt.text(0.4, 0.8, 'MaxPool1\n(2x2)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw Conv2 Layer
    rect3 = patches.FancyBboxPatch((0.55, 0.7), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightblue', linewidth=2)
    ax.add_patch(rect3)
    plt.text(0.65, 0.8, 'Conv2\n(6, 16, 5)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw Pool2 Layer
    rect4 = patches.FancyBboxPatch((0.8, 0.7), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightgreen', linewidth=2)
    ax.add_patch(rect4)
    plt.text(0.9, 0.8, 'MaxPool2\n(2x2)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw Flatten Layer
    rect5 = patches.FancyBboxPatch((0.05, 0.4), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightcoral', linewidth=2)
    ax.add_patch(rect5)
    plt.text(0.15, 0.5, 'Flatten\n(16*42*87)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw FC1 Layer
    rect6 = patches.FancyBboxPatch((0.3, 0.4), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightyellow', linewidth=2)
    ax.add_patch(rect6)
    plt.text(0.4, 0.5, 'FC1\n(16*42*87 -> 120)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw FC2 Layer
    rect7 = patches.FancyBboxPatch((0.55, 0.4), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightyellow', linewidth=2)
    ax.add_patch(rect7)
    plt.text(0.65, 0.5, 'FC2\n(120 -> 84)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw FC3 Layer
    rect8 = patches.FancyBboxPatch((0.8, 0.4), 0.2, 0.2, boxstyle="round,pad=0.1",
                                   edgecolor='black', facecolor='lightyellow', linewidth=2)
    ax.add_patch(rect8)
    plt.text(0.9, 0.5, 'FC3\n(84 -> 1)',
             horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')

    # Draw Arrows
    arrowprops = dict(facecolor='black', arrowstyle='->', lw=2)
    ax.annotate('', xy=(0.3, 0.8), xytext=(0.2, 0.8), arrowprops=arrowprops)
    ax.annotate('', xy=(0.55, 0.8), xytext=(0.45, 0.8), arrowprops=arrowprops)
    ax.annotate('', xy=(0.8, 0.8), xytext=(0.7, 0.8), arrowprops=arrowprops)
    ax.annotate('', xy=(0.3, 0.5), xytext=(0.2, 0.5), arrowprops=arrowprops)
    ax.annotate('', xy=(0.55, 0.5), xytext=(0.45, 0.5), arrowprops=arrowprops)
    ax.annotate('', xy=(0.8, 0.5), xytext=(0.7, 0.5), arrowprops=arrowprops)

    # Set limits and remove axes
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.axis('off')

    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the CNN architecture
draw_cnn_architecture()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(12, 8))

    # Define layer sizes
    layers = [
        ("Input\n(num_input_time_steps)", (1, 1)),
        ("Conv2D\n(6 filters, 3x3)", (2, 1)),
        ("MaxPool2D\n(2x2)", (2, 1)),
        ("Conv2D\n(16 filters, 5x5)", (2, 1)),
        ("MaxPool2D\n(2x2)", (2, 1)),
        ("Linear\n(120)", (2, 1)),
        ("Linear\n(84)", (2, 1)),
        ("Linear\n(1)", (2, 1)),
    ]

    # Positioning of layers
    x_pos = 1
    for layer, size in layers:
        rect = patches.Rectangle((x_pos, 1), size[0], size[1], linewidth=2, edgecolor='black', facecolor='lightblue')
        ax.add_patch(rect)
        ax.text(x_pos + size[0]/2, 1 + size[1]/2, layer, ha='center', va='center', fontsize=10)
        x_pos += size[0] + 1  # Move to the right for the next layer

    # Draw arrows
    for i in range(len(layers) - 1):
        ax.annotate('', xy=(i + 3, 1.5), xytext=(i + 2, 1.5),
                    arrowprops=dict(arrowstyle='->', lw=1.5))

    # Set limits and labels
    ax.set_xlim(0, x_pos)
    ax.set_ylim(0, 3)
    ax.axis('off')  # Turn off the axis
    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the architecture
draw_cnn_architecture()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(12, 8))

    # Define layer sizes, labels, and colors
    layers = [
        ("Input\n(num_input_time_steps)", (1, 1), 'lightgrey'),
        ("Conv2D\n(6 filters, 3x3)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Conv2D\n(16 filters, 5x5)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Linear\n(120)", (2, 1), 'lightcoral'),
        ("Linear\n(84)", (2, 1), 'lightcoral'),
        ("Linear\n(1)", (2, 1), 'lightcoral'),
    ]

    # Positioning of layers
    x_pos = 1
    for layer, size, color in layers:
        rect = patches.Rectangle((x_pos, 1), size[0], size[1], linewidth=2, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(x_pos + size[0]/2, 1 + size[1]/2, layer, ha='center', va='center', fontsize=10)
        x_pos += size[0] + 1  # Move to the right for the next layer

    # Draw arrows
    for i in range(len(layers) - 1):
        ax.annotate('', xy=(i + 2.5 + 1, 1.5), xytext=(i + 2.5, 1.5),
                    arrowprops=dict(arrowstyle='->', lw=1.5))

    # Set limits and labels
    ax.set_xlim(0, x_pos)
    ax.set_ylim(0, 3)
    ax.axis('off')  # Turn off the axis
    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the architecture
draw_cnn_architecture()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(8, 12))

    # Define layer sizes, labels, and colors
    layers = [
        ("Input\n(num_input_time_steps)", (2, 1), 'lightgrey'),
        ("Conv2D\n(6 filters, 3x3)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Conv2D\n(16 filters, 5x5)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Linear\n(120)", (2, 1), 'lightcoral'),
        ("Linear\n(84)", (2, 1), 'lightcoral'),
        ("Linear\n(1)", (2, 1), 'lightcoral'),
    ]

    # Positioning of layers (inverted y-axis)
    y_pos = 0  # Start from the bottom
    for layer, size, color in reversed(layers):
        rect = patches.Rectangle((1, y_pos), size[0], size[1], linewidth=2, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(1 + size[0]/2, y_pos + size[1]/2, layer, ha='center', va='center', fontsize=10)
        y_pos += size[1] + 0.5  # Move up for the next layer

    # Draw arrows (from top to bottom)
    for i in range(len(layers) - 1):
        ax.annotate('', xy=(2, (i + 1) * (1 + 0.5)), xytext=(2, i * (1 + 0.5) + 1),
                    arrowprops=dict(arrowstyle='->', lw=1.5))

    # Set limits and labels
    ax.set_xlim(0, 4)
    ax.set_ylim(0, y_pos)
    ax.axis('off')  # Turn off the axis
    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the architecture
draw_cnn_architecture()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(8, 12))

    # Define layer sizes, labels, and colors
    layers = [
        ("Input\n(num_input_time_steps)", (2, 1), 'lightgrey'),
        ("Conv2D\n(6 filters, 3x3)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Conv2D\n(16 filters, 5x5)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Linear\n(120)", (2, 1), 'lightcoral'),
        ("Linear\n(84)", (2, 1), 'lightcoral'),
        ("Linear\n(1)", (2, 1), 'lightcoral'),
    ]

    # Positioning of layers (inverted y-axis)
    y_pos = 0  # Start from the bottom
    for layer, size, color in reversed(layers):
        rect = patches.Rectangle((1, y_pos), size[0], size[1], linewidth=2, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(1 + size[0]/2, y_pos + size[1]/2, layer, ha='center', va='center', fontsize=10)
        y_pos += size[1] + 0.5  # Move up for the next layer

    # Draw arrows (from bottom to top)
    for i in range(len(layers) - 1):
        ax.annotate('', xy=(2, i * (1 + 0.5)), xytext=(2, (i + 1) * (1 + 0.5)),
                    arrowprops=dict(arrowstyle='->', lw=1.5))

    # Set limits and labels
    ax.set_xlim(0, 4)
    ax.set_ylim(0, y_pos)
    ax.axis('off')  # Turn off the axis
    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the architecture
draw_cnn_architecture()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_cnn_architecture():
    fig, ax = plt.subplots(figsize=(8, 12))

    # Define layer sizes, labels, and colors
    layers = [
        ("Input\n(num_input_time_steps)", (2, 1), 'lightgrey'),
        ("Conv2D\n(6 filters, 3x3)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Conv2D\n(16 filters, 5x5)", (2, 1), 'lightblue'),
        ("MaxPool2D\n(2x2)", (2, 1), 'lightgreen'),
        ("Linear\n(120)", (2, 1), 'lightcoral'),
        ("Linear\n(84)", (2, 1), 'lightcoral'),
        ("Linear\n(1)", (2, 1), 'lightcoral'),
    ]

    # Positioning of layers (inverted y-axis)
    y_pos = 0  # Start from the bottom
    for layer, size, color in reversed(layers):
        rect = patches.Rectangle((1, y_pos), size[0], size[1], linewidth=2, edgecolor='black', facecolor=color)
        ax.add_patch(rect)
        ax.text(1 + size[0]/2, y_pos + size[1]/2, layer, ha='center', va='center', fontsize=10)
        y_pos += size[1] + 0.5  # Move up for the next layer

    # Draw arrows (from bottom to top), adjusted to avoid overflow
    for i in range(len(layers) - 1):
        start_y = i * (1 + 0.5) + 0.5  # Start of the arrow
        end_y = (i + 1) * (1 + 0.5)    # End of the arrow
        ax.annotate('', xy=(2, start_y), xytext=(2, end_y),
                    arrowprops=dict(arrowstyle='->', lw=1.5, connectionstyle='arc3,rad=0.1'))

    # Set limits and labels
    ax.set_xlim(0, 4)
    ax.set_ylim(0, y_pos)
    ax.axis('off')  # Turn off the axis
    plt.title('CNN Architecture', fontsize=16)
    plt.show()

# Call the function to draw the architecture
draw_cnn_architecture()
